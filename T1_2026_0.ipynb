# %% [markdown]
# # Tarea 1

# %% [markdown]
# Fecha de entrega:
# Sábado 10 de Enero, 11.59pm
# En la entrega, colocar como nombre del archivo "T1_ApellidoNombre.ipynb" . e.g. "T1_SolisCarla.ipynb"
#
# La parte 1 consta de 3 ejercicios.
# La parte 2 consta de 4 ejercicios, elige 3 para resolver.
#
# Comentarios generales:
#
# - No olvidar que python usa el snake_case (o minúsculas separadas por subguión) para llamar a sus variables.
# - No nombrar variables con acentos porque algunas veces, dependiendo de la máquina en la que se corra, esto será aceptado o no.
# - Leer claramente qué es lo que pide la pregunta.

# %% [markdown]
# ## Parte 1

# %% [markdown]
# Ejemplo:  Utilizando sólo los siguientes inputs numéricos: ```5``` y ```2```  , maneje los operadores tal que el output sea ```120```. Crea una variable con el resultado.

# %%
#Respuesta
output = (5*2)**2 + 5*2**2
print(output)

# %% [markdown]
# 1. "Un jugoso zumo de piña y kiwi bien frío es exquisito y no lleva alcohol" es ejemplo de un conocido panagrama, los cuales son textos que usan todas las letras del alfabeto español.
# Crea una variable llamada  `panagrama` y comprueba que la frase contenga al menos 27 letras únicas.
# La respuesta debe ser un booleano.
# (Recomendación: Convertir el texto a minúscula, no te preocupes por los acentos, por ahora).

# %%
# tu respuesta aquí

# %% [markdown]
# 2. Con la [reducción del IGV para restaurantes y hoteles](https://orientacion.sunat.gob.pe/reduccion-del-igv-para-restaurantes-hoteles-y-alojamiento-turisticos-1#:~:text=Destinado%20a%20las%20micro%20y,IGV%208%25%20%2B%20IPM%202%25), los restaurantes pagan el 10% de IGV en vez del 18%. Un restaurante factura 3426 soles diarios, en promedio, después de impuestos. Calcule el valor base (el IGV es 10% sobre el valor base, ó 1 + .1).
#
# Calcule, utilizando el valor base, cuánto es el descuento del IGV en soles (o el 8% de este valor base).
#
# Cree una variable para cada uno de los siguientes:
# - porcentaje de IGV
# - el total de facturación
# - el monto del impuesto
# - el valor base sin impuesto
# - el descuento de IGV en soles (18% - 10%). Puedes comprobar tu fórmula con cualquier recibo de pago que detalle el IGV.

# %%
# tu respuesta aquí

# %% [markdown]
# 3. Una conocida petrolera debe volver a compensar a  1023 familias que se dedican a la pesca por la contaminación causada en el mar donde pescan. El nuevo monto negociado es de 1200 millones de soles, sin embargo, una cláusula del contrato dice que el monto de compensación tiene que ser un número entero. ¿Cuántos soles adicionales se le  tiene  que agregar al monto negociado para que las familias reciban una cantidad entera,  asumiendo que para lograr este número entero, hay que elevar el monto total? (Pista: Acuérdate del  floor y el módulo).

# %%
# tu respuesta aquí

# %% [markdown]
# ## Parte 2

# %% [markdown]
# 1.
#
# a. Haz un for-loop que vaya del 3 al 42, pero que sólo tome los elementos impares. Imprime (print) cada uno de los elementos mientras vas iterando por ellos. Pista: Puedes usar rangos.
#
# b. Modifica tu programa para que, a medida que vayas iterando por los elementos, vayas sumando estos en una variable llamada total_suma, definida antes que el loop empiece. Utiliza un operador de asignación aumentada.

# %%
# tu respuesta aquí

# %% [markdown]
# 2. Vamos a proyectar la población de un país pequeño de aquí a 15 años. Asumiremos que las personas no migran fuera de este país.
#
# La fórmula que utilizaremos es la siguiente:
#
#
# $P_{1} = P_{0} + P_{0} \cdot \text{tasa\_natalidad}
#           - P_{0} \cdot \text{tasa\_mortalidad}$
#
# La población en el tiempo 1, es igual a la (población en el momento 0) +  la (población en el momento 0)* tasa de natalidad - (població en el momento 0) * tasa de mortalidad.
# Para los siguientes años (2,3,4...) tomar el valor del año anterior.
#
# Los parámetros son los siguientes:
# - Asume una población inicial de 2 millones de personas.
# - La tasa de natalidad es 0.0159
# - La tasa de mortalidad es 0.0075

# %%
# tu respuesta aquí

# %% [markdown]
# 3.  Asumamos que en el año 0 ocurre un shock que ocasiona una migración anual de 100,000 personas.
# La nueva fórmula es:
#
# $P_{1} = P_{0} + P_{0} \cdot \text{tasa\_natalidad}
#           - P_{0} \cdot \text{tasa\_mortalidad} - migracion$
#
# Si definimos el colapso demográfico como una población menor a 500,000 personas, ¿en cuantos años ocurre esto?

# %%
# tu respuesta aquí

# %% [markdown]
# 4. Tenemos el siguiente diccionario de horas en diferentes ciudades, ajustados a su desviación del _Greenwich Mean Time_ (GMT):
#
# ``` python
# gmt_ciudades = {
#     "Londres": 0,
#     "Madrid": +1,
#     "París": +1,
#     "Nueva York": -5,
#     "Ciudad de México": -6,
#     "Lima": -5,
#     "Buenos Aires": -3,
#     "Asunción": -4,
#     "Tokio": +9,
#     "Sídney": +10
# }
# ```
#
# Vamos a escribir un programa sencillo que convierta horas entre ciudades. Para ello haremos lo siguiente:
# - crea una hora a convertir.
# - definir una `ciudad_base` y una `ciudad_conversion`. Estos serán strings que corresponden a algún par de llaves-ciudad entre las que queramos hacer la equivalencia. (Por ejemplo, "Lima" y "Buenos Aires").
# - Realiza las operaciones correspondientes (pista: convierte la hora a GMT 0, después cámbialo a la hora solicitada).
# - verifica que la hora a convertir no sea negativa, ni mayor a 24.

# %%
ciudad_base = 'Lima' #ejemplo
ciudad_conversion = 'Tokio'  # ejemplo

gmt_ciudades = {
    "Londres": 0,
    "Madrid": +1,
    "París": +1,
    "Nueva York": -5,
    "Ciudad de México": -6,
    "Lima": -5,
    "Buenos Aires": -3,
    "Asunción": -4,
    "Tokio": +9,
    "Sídney": +10
}

# Tu código aquí.
